# %% [markdown]
# # Travelling Salesman:

# %% [markdown]
# ## Document review(s)

# %% [markdown]
# # 1 - Abstract
#
# In the corporate sector, there are many problems that decision-makers strive to resolve and offer the most productive working practices at the most profitble cost. One of the challenges we wanted to tackle in this project is delivery of goods.
#
#
# The model developed for this research optimizes the cost (duration of travel) of shipping products from Venice to Milan while passing through other cities in Veneto.  This model includes specifications that are taken from the real world, such as the daily demand for commodities and a deadline. The deadline is the maximul time  the traveler should spend in his trip from Venice to Milan.
#
#
# The model aims to determine the optimal delivery route, maximize  the number of parcels delivered while respecting the deadline and minimizing the travel time.
#
#
# The methodology used to develop this model has different steps. First a formulation of the problem must be generated, this formulation will help define the parameters, the decision variables, the objective function and the constraints for the model to run.
#
#
# In conclusion, our goal and the final result of the model is to determine the most efficient route between locations that saves travel expenses and ensures that all goods are delivered for a given daily demand using adequate techniques.

# %% [markdown]
# # 2 - Acronyms and definitions

# %% [markdown]
# - *Distance: The distances used in this project are a result of a mathematical equation that has the latitude and longitude of the two points as parameters. This method assumes that the earth is a sphere, and the distance doesn't take routes and roads in consideration, therefore it is "as the crow flies"*.
#
# - *Time: The time spent by the traveler to go from point A to point B is solely dependant on the driving speed of the traveler, for this project, we assume that the traveler has a constant speed of 60km/h*.

# %% [markdown]
# # 3 - Problem statement
#
# Gonzales Company is planning a business trip through the Veneto region in Italy, with the goal of visiting as many cities as possible on their way to Milan. The trip will start in Venice and end in Milan. The company has limited time and wants to maximize the number of parcels delivered while adhering to certain constraints.

# %% [markdown]
# # 4 - System

# %% [markdown]
# ## 4.1 - Agents/DMs
# *Decision  Maker:*
# - The Courier.
#
# ## 4.2 - Assumptions
# *Demand:*
# - The demand of each city is proportionate to its population
# - The Courier's travel speed is constant, wether in the city or in the highway.
# - The Earth is a sphere (In order to get the distance from the coordinates)

# %% [markdown]
# # Preliminary operations
# - First we need to set up the necessary environment for solving the optimization problem using Pyomo.
# - We will be getting our data from Drive, therefore colab must be imported
# - GLPK must be imported in order to solve the model
# - Pandas must be imported to manipulate the data
# - distance must be imported to calculate the distance between the coordinates

# %%
# Preliminary operations' code
import pandas as pd
from geopy.distance import distance


working_in_colab = True # Set this variable equal to True if you are working in Colab, False otherwise
if working_in_colab:
    # WARNING: On Colab only
    # This needs to be done once at the start of each session.
    # !pip install -q pyomo              # Quiet installation of pyomo using pip.
    # !apt-get install -y -qq coinor-cbc # Installation of COIN-OR CBC.
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)   # Mount your drive

if working_in_colab:
    input_directory = "/content/drive/MyDrive/data/italycoord/"
    output_directory = "/content/drive/MyDrive/data/italycoord/"
    cbc_path = "/usr/bin/cbc"
else:
    input_directory = "./Input/"
    output_directory = "./Output/"
    cbc_path = "C:/Program Files/Cbc/bin/cbc.exe" # write the path of the cbc.exe file on your pc

# Preliminary operations' code
input_directory = "./Input/"
output_directory = "./Output/"
cbc_path = "C:/Program Files/Cbc/bin/cbc.exe" # write the path of the cbc.exe file on your pc

#COIN-OR CBC is a multi-threaded open-source Coin-or branch and cut mixed-integer linear programming solver
# !apt-get install -y -qq coinor-cbc
#pyomo
# !pip install -q pyomo

# !apt-get install -y -qq glpk-utils

from pyomo.environ import *
# Out:
# Mounted at /content/drive

# %% [markdown]
# # 5 - Data

# %% [markdown]
# - The source of the coordinates of the cities is taken from our course's moodle page 'Italycoord.csv'

# %%
import pandas as pd
# code that reads the input data files
#Coordinate distances was taken from the course's moodle
cities = ['Belluno','Feltre',"Cortina d'Ampezzo",'Padova','Abano Terme','Este','Rovigo','Adria','Porto Tolle','Treviso','Conegliano','Montebelluna','Venezia','Chioggia','Mirano','Verona','Bardolino','Peschiera del Garda','Vicenza','Bassano del Grappa','Marostica']

#coords = pd.read_csv('/content/drive/MyDrive/data/italycoord/itacoordcity.csv',delimiter=';', encoding='ISO-8859-1')
coords = pd.read_csv('drive/MyDrive/ItalyCoord.csv',delimiter=';', encoding='ISO-8859-1')

#Cities
coords = coords[coords['comune'].isin(cities)]

# Create an empty distance matrix
n_regions = len(coords)
Data = pd.DataFrame(index=coords['comune'], columns=coords['comune'])
# Calculate the distances between all pairs of regions
for i in range(n_regions):
    for j in range(i+1, n_regions):
        coord1 = (coords.iloc[i]['lat'], coords.iloc[i]['lng'])
        coord2 = (coords.iloc[j]['lat'], coords.iloc[j]['lng'])
        dist = distance(coord1, coord2).km
        Data.iloc[i,j] = dist
        Data.iloc[j,i] = dist

#Dictionnary of distances
distances = {}
for i in range(len(Data)):
  for j in range(len(Data)):
    if j!=i:
      distances[(Data.index[i],Data.columns[j])] = Data.iloc[i,j]
new_dict = {}
for key, value in distances.items():
    if key not in new_dict:
        new_dict[key] = value
#new_dict
# code that defines the dictionaries and/or frames used in the model.

# %% [markdown]
# ### Time Matrix
# We used the distances between each pair of cities to calculate the time spent on the road by the driver to reach a specific city and we stored them under each pair of city

# %%
from geopy.distance import distance
# Initialize an empty dictionary to hold the travel times
travel_times = {}

# Loop over the keys in the 'distances' dictionary
for key in distances.keys():
    # Get the distance between the two cities
    distance = distances[key]

    # Calculate the time taken to travel between the cities at 60 km/h
    time = distance / 60.0  # hours
    time *= 60  # convert to minutes

    # Reverse the order of the cities in the key to get the key for the
    # opposite direction (e.g., ('city1', 'city2') becomes ('city2', 'city1'))
    reverse_key = tuple(reversed(key))

    # Add the travel time to the 'travel_times' dictionary for both directions
    travel_times[key] = time
    travel_times[reverse_key] = time

# Now the 'travel_times' dictionary should have keys in the form ('city1', 'city2')
# and values representing the time taken to travel from 'city1' to 'city2' in minutes

# %% [markdown]
# ## 5.1 Mathematical  Model

# %% [markdown]
# ### 5.1.2 - Model

# %%
#Declare the Modelµ
model = AbstractModel()

# %% [markdown]
# ### 5.1.3 - Sets

# %% [markdown]
# *Cities/nodes*
#
# - Each node is a representation of a city visited or waiting to  be visited. These cities have characteristics such as:
#
# *Arcs/edges*
#
# - They link the cities in the graphical representation and specify the time required to reach city j starting from city i.

# %%
model.NODES = Set()
model.ARCS = Set(within = model.NODES*model.NODES)

# %% [markdown]
# ### 5.1.4 - Parameters

# %% [markdown]
# - NetDemand: Created for the sole purpose of ensuring that the Courier starts his journey in a specific city, and ends in a specific city.
# - Packages: The demand of each city
# - Cost: The time spent by the courier from a city to a different city
# - Alpha: The weight the company wishes to determine on the objective function

# %%
#Parameters
model.netDemand = Param(model.NODES) #used to get from veince(-1) to milan(1)
model.packages = Param(model.NODES)
model.cost = Param(model.ARCS)
model.alpha = Param(default=0) # weight of demand in objective function
#alpha == 0 ==> shortest distance

# %% [markdown]
# ### 5.1.5 - Variables

# %% [markdown]
# - u[i]: The position of each city in the tour
# - x[i,j]: 1 if the courier goes from city i to city j, 0 otherwise

# %%
# New variables ordr of nds
model.u = Var(model.NODES, within=NonNegativeIntegers)
#Decision Variables sel or no
model.x = Var(model.ARCS , within = Binary)

# %% [markdown]
# ### 5.1.6 - Constraints and Objective

# %% [markdown]
# **Objective Function**: aims to balance the total demand satisfied with the cost of the route.
#
# Let $C$ be the set of cities to be visited, and let $p_j$ be the demand (interchangable with packages) in city $j$. Let $t_{i,j}$ be the travel time between cities $i$ and $j$, and let $T$ be the maximum allowable travel time.
#
# We can then formulate the objective as follows:
#
# \begin{align*}
# \text{maximize} \quad & \alpha\sum_{i,j\in C}  x_{i,j}p_j - (1-\alpha)\sum_{i,j\in C} x_{i,j}t_{i,j}
# \end{align*}
#
# where $x_{i,j}$ is a binary variable that indicates whether we travel from city $i$ to city $j$ along the route, and $\alpha$ is a weight parameter that balances the importance of demand satisfaction and cost minimization. The objective function aims to maximize the total demand satisfied along the route, while also minimizing the cost of traveling between cities.
#
# <br>
#
# **We want to find a route that starts at city $a$ and ends at city $b$, subject to the following constraints:**
#
# The total travel time does not exceed $T$: $\sum_{i,j\in C} t_{i,j} x_{i,j} \leq T$.<br>
#
# Net Demand Rule: $\sum_{k\in C} x_{k,i} - \sum_{j\in C} x_{i,j} = d_i$ for all $i\in C$
#
# Subtour elimination constraint: $u_{i} - u_{j} + \sum_{i,j\in S} x_{i,j} \leq |S|-1$ for all $S\subset C$, $a\in S$, and $b\notin S$.<br>
# The number of cities visited should be at least $n$: $\sum_{i,j\in C} x_{i,j} \geq n$.<br>
# The number of cities visited should be at most $m$: $\sum_{i,j\in C} x_{i,j} \leq m$.<br>
#
# Where $C$ is the set of cities, $T$ is the maximum travel time, $p$ is the demand of the city, and the $d$ is the Net Demand of each city. $x_{i,j}$ is a binary decision variable that equals 1 if the route goes from city $i$ to city $j$, and $t_{i,j}$ represent the travel time and the time spent in the trip from city $i$ to city $j$, respectively.

# %%
#Objective Function
def obj_rule(model):
    return (model.alpha * sum(model.x[i,j]*model.packages[j] for (i,j) in model.ARCS)) - ((1 - model.alpha) * sum(model.x[i,j]*model.cost[i,j] for (i,j) in model.ARCS))
model.obj = Objective(rule = obj_rule, sense = maximize)


#Constraints
#He shouldnt stay for more than a particular number of minutes
def deadline_constraint(model):
  T = 360
  return sum(model.x[i,j]*model.cost[i,j] for (i,j) in model.ARCS) <= T
model.deadline_constraint = Constraint(rule=deadline_constraint)



#To make sure that the starting city is venezia and the arrival city is Milano
def net_demand_rule(model,i):
  return (sum(model.x[k,i] for k in model.NODES if (k,i) in model.ARCS)  - sum(model.x[i,j] for j in model.NODES if (i,j) in model.ARCS) == model.netDemand[i])
model.netDemandConstraints = Constraint(model.NODES , rule = net_demand_rule)

# Subtour elimination constraint
def no_subtours_rule(model, i, j):
    if i != j and (i, j) in model.ARCS:
        return model.u[i] - model.u[j] + len(model.NODES)*model.x[i,j] <= len(model.NODES)-1
    else:
        return Constraint.Skip
model.no_subtours = Constraint(model.ARCS, rule=no_subtours_rule)


'''
# Visit both A & B
def visit_A_and_B_rule(model):
  A = 'Marostica'
  B = 'Belluno'
  return sum(model.x[i, A] for i in model.NODES if i!=A) + sum(model.x[i, B] for i in model.NODES if i!=B) == 2
model.visit_A_and_B = Constraint(rule=visit_A_and_B_rule)
'''

# Visit either A or B
def visit_either_A_and_B_rule(model):
  A = 'Feltre'
  B = 'Este'
  return sum(model.x[i, A] for i in model.NODES if i!=A) + sum(model.x[i, B] for i in model.NODES if i!=B) == 1
model.visit_either_A_and_B_rule = Constraint(rule=visit_either_A_and_B_rule)


'''
#If city A is visited, then city B must be visited
def visit_B_if_A_visited(model):
  A = 'Feltre'
  B = 'Este'
  return (sum(model.x[j,B] for j in model.NODES if j!=B) >= sum(model.x[i,A] for i in model.NODES if i!=A))
model.visit_B_if_A_visited = Constraint(rule=visit_B_if_A_visited)'''

'''
#If city A is visited, then city B must NOT be visited
def dont_visit_B_if_A_visited(model):
  A = 'Porto_Tolle'
  B = 'Adria'
  return (sum(model.x[j,B] for j in model.NODES if j!=B) <= 1 - sum(model.x[i,A] for i in model.NODES if i!=A))
model.dont_visit_B_if_A_visited = Constraint(rule=dont_visit_B_if_A_visited)
'''

'''
#if city A is visited, then neither city B nor city C must be visited
def dont_visit_B_and_c_if_A_visited(model):
  A = 'Belluno'
  B = 'Abano_Terme'
  C = 'Este'
  return (sum(model.x[j,B] for j in model.NODES if j!=B) + sum(model.x[k,C] for k in model.NODES if k!=C) <= 2 - 2*sum(model.x[i,A] for i in model.NODES if i!=A))
model.dont_visit_B_and_c_if_A_visited = Constraint(rule=dont_visit_B_and_c_if_A_visited)
#Xic + XiB <= 2 - 2XiA
'''
'''
#n cities must be visited at least
def min_visits(model):
  n = 2
  return sum(model.x[i,j] for (i,j) in model.ARCS) >= n
model.min_visits = Constraint(rule=min_visits)
'''


'''def max_visits(model):
  return sum(model.x[i,j] for (i,j) in model.ARCS) <= 8
model.max_visits = Constraint(rule=max_visits)'''



#These cities must be visited
def cities_to_visit(model):
  subset = ['Belluno']
  l = len(subset)
  return sum(model.x[i,j] for (i,j) in model.ARCS if i!=j and j in subset) >= l
model.cities_to_visit = Constraint(rule=cities_to_visit)

# %% [markdown]
# ## Model Solution

# %%
#Solving the problem
data = DataPortal()
data.load(filename = '/content/sample_data/Data.dat', model=model)
instance = model.create_instance(data)

optimizer = SolverFactory('glpk', timelimit=1)
optimizer.options['mipgap'] = 0.01
optimizer.solve(instance)
instance.display()
result = {}
for i in instance.NODES:
    for j in instance.NODES:
        if (i,j) in instance.ARCS and instance.x[i,j].value == 1:
            print("From city", i, "to city", j)
            result[i]=j
# Out:
# Model unknown
#
#   Variables:
#     u : Size=22, Index=NODES
#         Key                 : Lower : Value : Upper : Fixed : Stale : Domain
#                 Abano_Terme :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                       Adria :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                   Bardolino :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#          Bassano_del_Grappa :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     Belluno :     0 :   1.0 :  None : False : False : NonNegativeIntegers
#                    Chioggia :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                  Conegliano :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#            Cortina_dAmpezzo :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                        Este :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                      Feltre :     0 :   2.0 :  None : False : False : NonNegativeIntegers
#                   Marostica :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                      Milano :     0 :   3.0 :  None : False : False : NonNegativeIntegers
#                      Mirano :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                Montebelluna :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                      Padova :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#         Peschiera_del_Garda :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                 Porto_Tolle :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                      Rovigo :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     Treviso :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     Venezia :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                      Verona :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#                     Vicenza :     0 :   0.0 :  None : False : False : NonNegativeIntegers
#     x : Size=462, Index=ARCS
#         Key                                           : Lower : Value : Upper : Fixed : Stale : Domain
#                              ('Abano_Terme', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                          ('Abano_Terme', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                 ('Abano_Terme', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Abano_Terme', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Abano_Terme', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                         ('Abano_Terme', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                   ('Abano_Terme', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Abano_Terme', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Abano_Terme', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                          ('Abano_Terme', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Abano_Terme', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Abano_Terme', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Abano_Terme', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Abano_Terme', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                ('Abano_Terme', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Abano_Terme', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Abano_Terme', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Abano_Terme', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Abano_Terme', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Abano_Terme', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Abano_Terme', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Adria', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Adria', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Adria', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Adria', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Adria', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Adria', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                         ('Adria', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                     ('Adria', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Adria', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Adria', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Adria', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Adria', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Adria', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Adria', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Adria', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Adria', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Adria', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Adria', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Adria', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Adria', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Adria', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                          ('Bardolino', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Bardolino', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                   ('Bardolino', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Bardolino', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Bardolino', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Bardolino', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Bardolino', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Bardolino', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Bardolino', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Bardolino', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Bardolino', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Bardolino', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                         ('Bardolino', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Bardolino', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                  ('Bardolino', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                          ('Bardolino', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Bardolino', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Bardolino', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Bardolino', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Bardolino', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Bardolino', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                 ('Bassano_del_Grappa', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Bassano_del_Grappa', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                   ('Bassano_del_Grappa', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Bassano_del_Grappa', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                    ('Bassano_del_Grappa', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                  ('Bassano_del_Grappa', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#            ('Bassano_del_Grappa', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Bassano_del_Grappa', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Bassano_del_Grappa', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                   ('Bassano_del_Grappa', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Bassano_del_Grappa', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Bassano_del_Grappa', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                ('Bassano_del_Grappa', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Bassano_del_Grappa', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#         ('Bassano_del_Grappa', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                 ('Bassano_del_Grappa', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Bassano_del_Grappa', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Bassano_del_Grappa', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Bassano_del_Grappa', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Bassano_del_Grappa', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Bassano_del_Grappa', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Belluno', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Belluno', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Belluno', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Belluno', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Belluno', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Belluno', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Belluno', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Belluno', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Belluno', 'Feltre') :     0 :   1.0 :     1 : False : False : Binary
#                              ('Belluno', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Belluno', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Belluno', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Belluno', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Belluno', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                    ('Belluno', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Belluno', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Belluno', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Belluno', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Belluno', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Belluno', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Belluno', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Chioggia', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Chioggia', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Chioggia', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                    ('Chioggia', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Chioggia', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Chioggia', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Chioggia', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Chioggia', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Chioggia', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Chioggia', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Chioggia', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Chioggia', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                          ('Chioggia', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Chioggia', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                   ('Chioggia', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Chioggia', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Chioggia', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Chioggia', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Chioggia', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Chioggia', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Chioggia', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                         ('Conegliano', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Conegliano', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Conegliano', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                  ('Conegliano', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Conegliano', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Conegliano', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                    ('Conegliano', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Conegliano', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Conegliano', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Conegliano', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Conegliano', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Conegliano', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Conegliano', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Conegliano', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                 ('Conegliano', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                         ('Conegliano', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Conegliano', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Conegliano', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Conegliano', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Conegliano', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Conegliano', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                   ('Cortina_dAmpezzo', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                         ('Cortina_dAmpezzo', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Cortina_dAmpezzo', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#            ('Cortina_dAmpezzo', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Cortina_dAmpezzo', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Cortina_dAmpezzo', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                    ('Cortina_dAmpezzo', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                          ('Cortina_dAmpezzo', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Cortina_dAmpezzo', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Cortina_dAmpezzo', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Cortina_dAmpezzo', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Cortina_dAmpezzo', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                  ('Cortina_dAmpezzo', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Cortina_dAmpezzo', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#           ('Cortina_dAmpezzo', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                   ('Cortina_dAmpezzo', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Cortina_dAmpezzo', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Cortina_dAmpezzo', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Cortina_dAmpezzo', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Cortina_dAmpezzo', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Cortina_dAmpezzo', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Este', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                     ('Este', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Este', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Este', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Este', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Este', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Este', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                          ('Este', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                    ('Este', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Este', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                                    ('Este', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                                    ('Este', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Este', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                                    ('Este', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Este', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Este', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                                    ('Este', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Este', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Este', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                                    ('Este', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Este', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Feltre', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Feltre', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Feltre', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Feltre', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Feltre', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Feltre', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Feltre', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Feltre', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                    ('Feltre', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Feltre', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Feltre', 'Milano') :     0 :   1.0 :     1 : False : False : Binary
#                                  ('Feltre', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Feltre', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Feltre', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Feltre', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Feltre', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Feltre', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Feltre', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Feltre', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Feltre', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Feltre', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                          ('Marostica', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Marostica', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Marostica', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                   ('Marostica', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Marostica', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Marostica', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Marostica', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Marostica', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Marostica', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Marostica', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Marostica', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Marostica', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                         ('Marostica', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Marostica', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                  ('Marostica', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                          ('Marostica', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Marostica', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Marostica', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Marostica', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Marostica', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Marostica', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Milano', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Milano', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Milano', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Milano', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Milano', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Milano', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Milano', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Milano', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                    ('Milano', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Milano', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Milano', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Milano', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Milano', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Milano', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Milano', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Milano', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Milano', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Milano', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Milano', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Milano', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Milano', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Mirano', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Mirano', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Mirano', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Mirano', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Mirano', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Mirano', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Mirano', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Mirano', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                    ('Mirano', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Mirano', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Mirano', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Mirano', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Mirano', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Mirano', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Mirano', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Mirano', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Mirano', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Mirano', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Mirano', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Mirano', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Mirano', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Montebelluna', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Montebelluna', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                         ('Montebelluna', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                ('Montebelluna', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Montebelluna', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                          ('Montebelluna', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Montebelluna', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                  ('Montebelluna', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Montebelluna', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Montebelluna', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                         ('Montebelluna', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Montebelluna', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Montebelluna', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Montebelluna', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#               ('Montebelluna', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Montebelluna', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Montebelluna', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Montebelluna', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Montebelluna', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Montebelluna', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Montebelluna', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Padova', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Padova', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Padova', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Padova', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Padova', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Padova', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Padova', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Padova', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                    ('Padova', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Padova', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Padova', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Padova', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Padova', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Padova', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Padova', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Padova', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Padova', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Padova', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Padova', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Padova', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Padova', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                ('Peschiera_del_Garda', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Peschiera_del_Garda', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                  ('Peschiera_del_Garda', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#         ('Peschiera_del_Garda', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                    ('Peschiera_del_Garda', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                   ('Peschiera_del_Garda', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                 ('Peschiera_del_Garda', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#           ('Peschiera_del_Garda', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Peschiera_del_Garda', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Peschiera_del_Garda', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                  ('Peschiera_del_Garda', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Peschiera_del_Garda', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Peschiera_del_Garda', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#               ('Peschiera_del_Garda', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Peschiera_del_Garda', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                ('Peschiera_del_Garda', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Peschiera_del_Garda', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                    ('Peschiera_del_Garda', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                    ('Peschiera_del_Garda', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Peschiera_del_Garda', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                    ('Peschiera_del_Garda', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Porto_Tolle', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Porto_Tolle', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                          ('Porto_Tolle', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                 ('Porto_Tolle', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Porto_Tolle', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Porto_Tolle', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                         ('Porto_Tolle', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                   ('Porto_Tolle', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Porto_Tolle', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Porto_Tolle', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                          ('Porto_Tolle', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Porto_Tolle', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Porto_Tolle', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Porto_Tolle', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Porto_Tolle', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                ('Porto_Tolle', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Porto_Tolle', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Porto_Tolle', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Porto_Tolle', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Porto_Tolle', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Porto_Tolle', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Rovigo', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Rovigo', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Rovigo', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Rovigo', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Rovigo', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Rovigo', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Rovigo', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Rovigo', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                    ('Rovigo', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Rovigo', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Rovigo', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Rovigo', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Rovigo', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Rovigo', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Rovigo', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Rovigo', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Rovigo', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Rovigo', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Rovigo', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Rovigo', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Rovigo', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Treviso', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Treviso', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Treviso', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Treviso', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Treviso', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Treviso', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Treviso', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Treviso', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Treviso', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Treviso', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Treviso', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Treviso', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Treviso', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Treviso', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Treviso', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                    ('Treviso', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Treviso', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Treviso', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Treviso', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Treviso', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Treviso', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Venezia', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Venezia', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Venezia', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Venezia', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Venezia', 'Belluno') :     0 :   1.0 :     1 : False : False : Binary
#                               ('Venezia', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Venezia', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                       ('Venezia', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Venezia', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Venezia', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Venezia', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Venezia', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Venezia', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                           ('Venezia', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Venezia', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                    ('Venezia', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Venezia', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Venezia', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Venezia', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Venezia', 'Verona') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Venezia', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Verona', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                   ('Verona', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Verona', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
#                      ('Verona', 'Bassano_del_Grappa') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Verona', 'Belluno') :     0 :   0.0 :     1 : False : False : Binary
#                                ('Verona', 'Chioggia') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Verona', 'Conegliano') :     0 :   0.0 :     1 : False : False : Binary
#                        ('Verona', 'Cortina_dAmpezzo') :     0 :   0.0 :     1 : False : False : Binary
#                                    ('Verona', 'Este') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Verona', 'Feltre') :     0 :   0.0 :     1 : False : False : Binary
#                               ('Verona', 'Marostica') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Verona', 'Milano') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Verona', 'Mirano') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Verona', 'Montebelluna') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Verona', 'Padova') :     0 :   0.0 :     1 : False : False : Binary
#                     ('Verona', 'Peschiera_del_Garda') :     0 :   0.0 :     1 : False : False : Binary
#                             ('Verona', 'Porto_Tolle') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Verona', 'Rovigo') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Verona', 'Treviso') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Verona', 'Venezia') :     0 :   0.0 :     1 : False : False : Binary
#                                 ('Verona', 'Vicenza') :     0 :   0.0 :     1 : False : False : Binary
#                            ('Vicenza', 'Abano_Terme') :     0 :   0.0 :     1 : False : False : Binary
#                                  ('Vicenza', 'Adria') :     0 :   0.0 :     1 : False : False : Binary
#                              ('Vicenza', 'Bardolino') :     0 :   0.0 :     1 : False : False : Binary
# ...
#                        ('Mirano', 'Cortina_dAmpezzo') :  None :  0.0 :  21.0
#                                    ('Mirano', 'Este') :  None :  0.0 :  21.0
#                                  ('Mirano', 'Feltre') :  None : -2.0 :  21.0
#                               ('Mirano', 'Marostica') :  None :  0.0 :  21.0
#                                  ('Mirano', 'Milano') :  None : -3.0 :  21.0
#                            ('Mirano', 'Montebelluna') :  None :  0.0 :  21.0
#                                  ('Mirano', 'Padova') :  None :  0.0 :  21.0
#                     ('Mirano', 'Peschiera_del_Garda') :  None :  0.0 :  21.0
#                             ('Mirano', 'Porto_Tolle') :  None :  0.0 :  21.0
#                                  ('Mirano', 'Rovigo') :  None :  0.0 :  21.0
#                                 ('Mirano', 'Treviso') :  None :  0.0 :  21.0
#                                 ('Mirano', 'Venezia') :  None :  0.0 :  21.0
#                                  ('Mirano', 'Verona') :  None :  0.0 :  21.0
#                                 ('Mirano', 'Vicenza') :  None :  0.0 :  21.0
#                       ('Montebelluna', 'Abano_Terme') :  None :  0.0 :  21.0
#                             ('Montebelluna', 'Adria') :  None :  0.0 :  21.0
#                         ('Montebelluna', 'Bardolino') :  None :  0.0 :  21.0
#                ('Montebelluna', 'Bassano_del_Grappa') :  None :  0.0 :  21.0
#                           ('Montebelluna', 'Belluno') :  None : -1.0 :  21.0
#                          ('Montebelluna', 'Chioggia') :  None :  0.0 :  21.0
#                        ('Montebelluna', 'Conegliano') :  None :  0.0 :  21.0
#                  ('Montebelluna', 'Cortina_dAmpezzo') :  None :  0.0 :  21.0
#                              ('Montebelluna', 'Este') :  None :  0.0 :  21.0
#                            ('Montebelluna', 'Feltre') :  None : -2.0 :  21.0
#                         ('Montebelluna', 'Marostica') :  None :  0.0 :  21.0
#                            ('Montebelluna', 'Milano') :  None : -3.0 :  21.0
#                            ('Montebelluna', 'Mirano') :  None :  0.0 :  21.0
#                            ('Montebelluna', 'Padova') :  None :  0.0 :  21.0
#               ('Montebelluna', 'Peschiera_del_Garda') :  None :  0.0 :  21.0
#                       ('Montebelluna', 'Porto_Tolle') :  None :  0.0 :  21.0
#                            ('Montebelluna', 'Rovigo') :  None :  0.0 :  21.0
#                           ('Montebelluna', 'Treviso') :  None :  0.0 :  21.0
#                           ('Montebelluna', 'Venezia') :  None :  0.0 :  21.0
#                            ('Montebelluna', 'Verona') :  None :  0.0 :  21.0
#                           ('Montebelluna', 'Vicenza') :  None :  0.0 :  21.0
#                             ('Padova', 'Abano_Terme') :  None :  0.0 :  21.0
#                                   ('Padova', 'Adria') :  None :  0.0 :  21.0
#                               ('Padova', 'Bardolino') :  None :  0.0 :  21.0
#                      ('Padova', 'Bassano_del_Grappa') :  None :  0.0 :  21.0
#                                 ('Padova', 'Belluno') :  None : -1.0 :  21.0
#                                ('Padova', 'Chioggia') :  None :  0.0 :  21.0
#                              ('Padova', 'Conegliano') :  None :  0.0 :  21.0
#                        ('Padova', 'Cortina_dAmpezzo') :  None :  0.0 :  21.0
#                                    ('Padova', 'Este') :  None :  0.0 :  21.0
#                                  ('Padova', 'Feltre') :  None : -2.0 :  21.0
#                               ('Padova', 'Marostica') :  None :  0.0 :  21.0
#                                  ('Padova', 'Milano') :  None : -3.0 :  21.0
#                                  ('Padova', 'Mirano') :  None :  0.0 :  21.0
#                            ('Padova', 'Montebelluna') :  None :  0.0 :  21.0
#                     ('Padova', 'Peschiera_del_Garda') :  None :  0.0 :  21.0
#                             ('Padova', 'Porto_Tolle') :  None :  0.0 :  21.0
#                                  ('Padova', 'Rovigo') :  None :  0.0 :  21.0
#                                 ('Padova', 'Treviso') :  None :  0.0 :  21.0
#                                 ('Padova', 'Venezia') :  None :  0.0 :  21.0
#                                  ('Padova', 'Verona') :  None :  0.0 :  21.0
#                                 ('Padova', 'Vicenza') :  None :  0.0 :  21.0
#                ('Peschiera_del_Garda', 'Abano_Terme') :  None :  0.0 :  21.0
#                      ('Peschiera_del_Garda', 'Adria') :  None :  0.0 :  21.0
#                  ('Peschiera_del_Garda', 'Bardolino') :  None :  0.0 :  21.0
#         ('Peschiera_del_Garda', 'Bassano_del_Grappa') :  None :  0.0 :  21.0
#                    ('Peschiera_del_Garda', 'Belluno') :  None : -1.0 :  21.0
#                   ('Peschiera_del_Garda', 'Chioggia') :  None :  0.0 :  21.0
#                 ('Peschiera_del_Garda', 'Conegliano') :  None :  0.0 :  21.0
#           ('Peschiera_del_Garda', 'Cortina_dAmpezzo') :  None :  0.0 :  21.0
#                       ('Peschiera_del_Garda', 'Este') :  None :  0.0 :  21.0
#                     ('Peschiera_del_Garda', 'Feltre') :  None : -2.0 :  21.0
#                  ('Peschiera_del_Garda', 'Marostica') :  None :  0.0 :  21.0
#                     ('Peschiera_del_Garda', 'Milano') :  None : -3.0 :  21.0
#                     ('Peschiera_del_Garda', 'Mirano') :  None :  0.0 :  21.0
#               ('Peschiera_del_Garda', 'Montebelluna') :  None :  0.0 :  21.0
#                     ('Peschiera_del_Garda', 'Padova') :  None :  0.0 :  21.0
#                ('Peschiera_del_Garda', 'Porto_Tolle') :  None :  0.0 :  21.0
#                     ('Peschiera_del_Garda', 'Rovigo') :  None :  0.0 :  21.0
#                    ('Peschiera_del_Garda', 'Treviso') :  None :  0.0 :  21.0
#                    ('Peschiera_del_Garda', 'Venezia') :  None :  0.0 :  21.0
#                     ('Peschiera_del_Garda', 'Verona') :  None :  0.0 :  21.0
#                    ('Peschiera_del_Garda', 'Vicenza') :  None :  0.0 :  21.0
#                        ('Porto_Tolle', 'Abano_Terme') :  None :  0.0 :  21.0
#                              ('Porto_Tolle', 'Adria') :  None :  0.0 :  21.0
#                          ('Porto_Tolle', 'Bardolino') :  None :  0.0 :  21.0
#                 ('Porto_Tolle', 'Bassano_del_Grappa') :  None :  0.0 :  21.0
#                            ('Porto_Tolle', 'Belluno') :  None : -1.0 :  21.0
#                           ('Porto_Tolle', 'Chioggia') :  None :  0.0 :  21.0
#                         ('Porto_Tolle', 'Conegliano') :  None :  0.0 :  21.0
#                   ('Porto_Tolle', 'Cortina_dAmpezzo') :  None :  0.0 :  21.0
#                               ('Porto_Tolle', 'Este') :  None :  0.0 :  21.0
#                             ('Porto_Tolle', 'Feltre') :  None : -2.0 :  21.0
#                          ('Porto_Tolle', 'Marostica') :  None :  0.0 :  21.0
#                             ('Porto_Tolle', 'Milano') :  None : -3.0 :  21.0
#                             ('Porto_Tolle', 'Mirano') :  None :  0.0 :  21.0
#                       ('Porto_Tolle', 'Montebelluna') :  None :  0.0 :  21.0
#                             ('Porto_Tolle', 'Padova') :  None :  0.0 :  21.0
#                ('Porto_Tolle', 'Peschiera_del_Garda') :  None :  0.0 :  21.0
#                             ('Porto_Tolle', 'Rovigo') :  None :  0.0 :  21.0
#                            ('Porto_Tolle', 'Treviso') :  None :  0.0 :  21.0
#                            ('Porto_Tolle', 'Venezia') :  None :  0.0 :  21.0
#                             ('Porto_Tolle', 'Verona') :  None :  0.0 :  21.0
#                            ('Porto_Tolle', 'Vicenza') :  None :  0.0 :  21.0
#                             ('Rovigo', 'Abano_Terme') :  None :  0.0 :  21.0
#                                   ('Rovigo', 'Adria') :  None :  0.0 :  21.0
#                               ('Rovigo', 'Bardolino') :  None :  0.0 :  21.0
#                      ('Rovigo', 'Bassano_del_Grappa') :  None :  0.0 :  21.0
#                                 ('Rovigo', 'Belluno') :  None : -1.0 :  21.0
#                                ('Rovigo', 'Chioggia') :  None :  0.0 :  21.0
#                              ('Rovigo', 'Conegliano') :  None :  0.0 :  21.0
#                        ('Rovigo', 'Cortina_dAmpezzo') :  None :  0.0 :  21.0
#                                    ('Rovigo', 'Este') :  None :  0.0 :  21.0
#                                  ('Rovigo', 'Feltre') :  None : -2.0 :  21.0
#                               ('Rovigo', 'Marostica') :  None :  0.0 :  21.0
#                                  ('Rovigo', 'Milano') :  None : -3.0 :  21.0
#                                  ('Rovigo', 'Mirano') :  None :  0.0 :  21.0
#                            ('Rovigo', 'Montebelluna') :  None :  0.0 :  21.0
#                                  ('Rovigo', 'Padova') :  None :  0.0 :  21.0
#                     ('Rovigo', 'Peschiera_del_Garda') :  None :  0.0 :  21.0
#                             ('Rovigo', 'Porto_Tolle') :  None :  0.0 :  21.0
#                                 ('Rovigo', 'Treviso') :  None :  0.0 :  21.0
#                                 ('Rovigo', 'Venezia') :  None :  0.0 :  21.0
#                                  ('Rovigo', 'Verona') :  None :  0.0 :  21.0
#                                 ('Rovigo', 'Vicenza') :  None :  0.0 :  21.0
#                            ('Treviso', 'Abano_Terme') :  None :  0.0 :  21.0
#                                  ('Treviso', 'Adria') :  None :  0.0 :  21.0
#                              ('Treviso', 'Bardolino') :  None :  0.0 :  21.0
#                     ('Treviso', 'Bassano_del_Grappa') :  None :  0.0 :  21.0
#                                ('Treviso', 'Belluno') :  None : -1.0 :  21.0
#                               ('Treviso', 'Chioggia') :  None :  0.0 :  21.0
#                             ('Treviso', 'Conegliano') :  None :  0.0 :  21.0
#                       ('Treviso', 'Cortina_dAmpezzo') :  None :  0.0 :  21.0
#                                   ('Treviso', 'Este') :  None :  0.0 :  21.0
#                                 ('Treviso', 'Feltre') :  None : -2.0 :  21.0
#                              ('Treviso', 'Marostica') :  None :  0.0 :  21.0
#                                 ('Treviso', 'Milano') :  None : -3.0 :  21.0
#                                 ('Treviso', 'Mirano') :  None :  0.0 :  21.0
#                           ('Treviso', 'Montebelluna') :  None :  0.0 :  21.0
#                                 ('Treviso', 'Padova') :  None :  0.0 :  21.0
#                    ('Treviso', 'Peschiera_del_Garda') :  None :  0.0 :  21.0
#                            ('Treviso', 'Porto_Tolle') :  None :  0.0 :  21.0
#                                 ('Treviso', 'Rovigo') :  None :  0.0 :  21.0
#                                ('Treviso', 'Venezia') :  None :  0.0 :  21.0
#                                 ('Treviso', 'Verona') :  None :  0.0 :  21.0
#                                ('Treviso', 'Vicenza') :  None :  0.0 :  21.0
#                            ('Venezia', 'Abano_Terme') :  None :  0.0 :  21.0
#                                  ('Venezia', 'Adria') :  None :  0.0 :  21.0
#                              ('Venezia', 'Bardolino') :  None :  0.0 :  21.0
#                     ('Venezia', 'Bassano_del_Grappa') :  None :  0.0 :  21.0
#                                ('Venezia', 'Belluno') :  None : 21.0 :  21.0
#                               ('Venezia', 'Chioggia') :  None :  0.0 :  21.0
#                             ('Venezia', 'Conegliano') :  None :  0.0 :  21.0
#                       ('Venezia', 'Cortina_dAmpezzo') :  None :  0.0 :  21.0
#                                   ('Venezia', 'Este') :  None :  0.0 :  21.0
#                                 ('Venezia', 'Feltre') :  None : -2.0 :  21.0
#                              ('Venezia', 'Marostica') :  None :  0.0 :  21.0
#                                 ('Venezia', 'Milano') :  None : -3.0 :  21.0
#                                 ('Venezia', 'Mirano') :  None :  0.0 :  21.0
#                           ('Venezia', 'Montebelluna') :  None :  0.0 :  21.0
#                                 ('Venezia', 'Padova') :  None :  0.0 :  21.0
#                    ('Venezia', 'Peschiera_del_Garda') :  None :  0.0 :  21.0
#                            ('Venezia', 'Porto_Tolle') :  None :  0.0 :  21.0
#                                 ('Venezia', 'Rovigo') :  None :  0.0 :  21.0
#                                ('Venezia', 'Treviso') :  None :  0.0 :  21.0
#                                 ('Venezia', 'Verona') :  None :  0.0 :  21.0
#                                ('Venezia', 'Vicenza') :  None :  0.0 :  21.0
#                             ('Verona', 'Abano_Terme') :  None :  0.0 :  21.0
#                                   ('Verona', 'Adria') :  None :  0.0 :  21.0
#                               ('Verona', 'Bardolino') :  None :  0.0 :  21.0
#                      ('Verona', 'Bassano_del_Grappa') :  None :  0.0 :  21.0
#                                 ('Verona', 'Belluno') :  None : -1.0 :  21.0
#                                ('Verona', 'Chioggia') :  None :  0.0 :  21.0
#                              ('Verona', 'Conegliano') :  None :  0.0 :  21.0
#                        ('Verona', 'Cortina_dAmpezzo') :  None :  0.0 :  21.0
#                                    ('Verona', 'Este') :  None :  0.0 :  21.0
#                                  ('Verona', 'Feltre') :  None : -2.0 :  21.0
#                               ('Verona', 'Marostica') :  None :  0.0 :  21.0
#                                  ('Verona', 'Milano') :  None : -3.0 :  21.0
#                                  ('Verona', 'Mirano') :  None :  0.0 :  21.0
#                            ('Verona', 'Montebelluna') :  None :  0.0 :  21.0
#                                  ('Verona', 'Padova') :  None :  0.0 :  21.0
#                     ('Verona', 'Peschiera_del_Garda') :  None :  0.0 :  21.0
#                             ('Verona', 'Porto_Tolle') :  None :  0.0 :  21.0
#                                  ('Verona', 'Rovigo') :  None :  0.0 :  21.0
#                                 ('Verona', 'Treviso') :  None :  0.0 :  21.0
#                                 ('Verona', 'Venezia') :  None :  0.0 :  21.0
#                                 ('Verona', 'Vicenza') :  None :  0.0 :  21.0
#                            ('Vicenza', 'Abano_Terme') :  None :  0.0 :  21.0
#                                  ('Vicenza', 'Adria') :  None :  0.0 :  21.0
#                              ('Vicenza', 'Bardolino') :  None :  0.0 :  21.0
#                     ('Vicenza', 'Bassano_del_Grappa') :  None :  0.0 :  21.0
#                                ('Vicenza', 'Belluno') :  None : -1.0 :  21.0
#                               ('Vicenza', 'Chioggia') :  None :  0.0 :  21.0
#                             ('Vicenza', 'Conegliano') :  None :  0.0 :  21.0
#                       ('Vicenza', 'Cortina_dAmpezzo') :  None :  0.0 :  21.0
#                                   ('Vicenza', 'Este') :  None :  0.0 :  21.0
#                                 ('Vicenza', 'Feltre') :  None : -2.0 :  21.0
#                              ('Vicenza', 'Marostica') :  None :  0.0 :  21.0
#                                 ('Vicenza', 'Milano') :  None : -3.0 :  21.0
#                                 ('Vicenza', 'Mirano') :  None :  0.0 :  21.0
#                           ('Vicenza', 'Montebelluna') :  None :  0.0 :  21.0
#                                 ('Vicenza', 'Padova') :  None :  0.0 :  21.0
#                    ('Vicenza', 'Peschiera_del_Garda') :  None :  0.0 :  21.0
#                            ('Vicenza', 'Porto_Tolle') :  None :  0.0 :  21.0
#                                 ('Vicenza', 'Rovigo') :  None :  0.0 :  21.0
#                                ('Vicenza', 'Treviso') :  None :  0.0 :  21.0
#                                ('Vicenza', 'Venezia') :  None :  0.0 :  21.0
#                                 ('Vicenza', 'Verona') :  None :  0.0 :  21.0
#     visit_either_A_and_B_rule : Size=1
#         Key  : Lower : Body : Upper
#         None :   1.0 :  1.0 :   1.0
#     cities_to_visit : Size=1
#         Key  : Lower : Body : Upper
#         None :   1.0 :  1.0 :  None
# From city Belluno to city Feltre
# From city Feltre to city Milano
# From city Venezia to city Belluno

# %%
cities_list = ['Venezia']

# Loop until we reach Milano
while cities_list[-1] != 'Milano':
    # Get the last city in the list
    last_city = cities_list[-1]

    # Find the next city in the dictionary
    next_city = result[last_city]

    # Add the next city to the list
    cities_list.append(next_city)

# Print the final list of cities
for i in cities_list:
  if i !='Milano':
    print(i,' -> ',end='')
  else:
    print(i)
# Out:
# Venezia  -> Belluno  -> Feltre  -> Milano

# %% [markdown]
# ## 5.3 - Analysis
# The model solution is reliable and  and applicable for real world small problems if provided the required data.
#
# It can also be altered in a way that the constraints are difference with accordance to different scenarios.
# For example we can impose the last city visited.
# We can also allow the driver to visit a city more than once.
# We can omit the penalty cost and add a bonus if parcels are delivered prior to their estimated time in an excellent state.
